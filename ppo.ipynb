# %%
# ============================================================
# INSTALLATION CELL - RUN THIS FIRST
# ============================================================

# !pip install -q gymnasium[atari,accept-rom-license]
# !pip install -q ale-py
# !pip install -q stable-baselines3[extra]
# !apt-get install -y ffmpeg > /dev/null 2>&1
# !AutoROM --accept-license

print("✅ Installation complete!")
print("⚠️  Now click: Runtime → Restart session")
# Out:
# WARNING: gymnasium 1.2.2 does not provide the extra 'accept-rom-license'
# AutoROM will download the Atari 2600 ROMs.
# They will be installed to:
# 	/usr/local/lib/python3.12/dist-packages/AutoROM/roms
#
# Existing ROMs will be overwritten.
# ✅ Installation complete!
# ⚠️  Now click: Runtime → Restart session

# %%
# ============================================================
# INSTALLATION CELL - RUN THIS FIRST
# ============================================================

# !pip install -q gymnasium[atari,accept-rom-license]
# !pip install -q ale-py
# !pip install -q stable-baselines3[extra]
# !apt-get install -y ffmpeg > /dev/null 2>&1
# !AutoROM --accept-license

print("✅ Installation complete!")
print("⚠️  Now click: Runtime → Restart session")
# Out:
# WARNING: gymnasium 1.2.2 does not provide the extra 'accept-rom-license'
# AutoROM will download the Atari 2600 ROMs.
# They will be installed to:
# 	/usr/local/lib/python3.12/dist-packages/AutoROM/roms
#
# Existing ROMs will be overwritten.
# ✅ Installation complete!
# ⚠️  Now click: Runtime → Restart session

# %%
# ============================================================
# TRAINING CODE - RUN AFTER RESTART (FIXED)
# ============================================================

import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv, VecVideoRecorder
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.atari_wrappers import AtariWrapper
import ale_py

# ----------------------------
# CREATE ENVIRONMENT WITH PROPER WRAPPERS
# ----------------------------
def make_env():
    env = gym.make(
        "ALE/Freeway-v5",
        render_mode="rgb_array"
    )
    # AtariWrapper handles frame stacking, grayscale, and proper shape
    env = AtariWrapper(env)
    return env

# Test environment
print("🔍 Testing environment...")
test_env = make_env()
print(f"✅ Environment works!")
print(f"Observation shape: {test_env.observation_space.shape}")
test_env.close()

# Create vectorized environment
env = DummyVecEnv([make_env])

print("\n📊 Environment Info:")
print("Observation space:", env.observation_space)
print("Action space:", env.action_space)

# ----------------------------
# CREATE PPO MODEL
# ----------------------------
print("\n🤖 Creating PPO model...")
model = PPO(
    "CnnPolicy",
    env,
    learning_rate=2.5e-4,
    n_steps=2048,
    batch_size=64,
    gamma=0.99,
    verbose=1
)

# ----------------------------
# TRAIN
# ----------------------------
print("\n🚀 Training started... (this takes ~30-60 minutes)")
model.learn(total_timesteps=500_000)
model.save("ppo_freeway_agent")
print("\n✅ Training complete!")

# ----------------------------
# EVALUATE
# ----------------------------
print("\n📊 Evaluating...")
mean_reward, std_reward = evaluate_policy(
    model, env, n_eval_episodes=10, deterministic=True
)
print(f"🎯 Mean Reward: {mean_reward:.2f} ± {std_reward:.2f}")

# ----------------------------
# RECORD VIDEO
# ----------------------------
print("\n🎥 Recording video...")
video_env = DummyVecEnv([make_env])
video_env = VecVideoRecorder(
    video_env,
    "./videos/",
    record_video_trigger=lambda step: step == 0,
    video_length=2000,
    name_prefix="ppo-freeway"
)

obs = video_env.reset()
for _ in range(2000):
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, done, info = video_env.step(action)

video_env.close()
print("✅ Video saved in ./videos/")

# ----------------------------
# DISPLAY VIDEO
# ----------------------------
import os
from IPython.display import HTML
from base64 import b64encode

video_files = [f for f in os.listdir("./videos/") if f.endswith(".mp4")]
if video_files:
    video_path = os.path.join("./videos/", video_files[0])
    with open(video_path, "rb") as f:
        video_data = f.read()
    data_url = "data:video/mp4;base64," + b64encode(video_data).decode()
    display(HTML(f'<video width="400" controls><source src="{data_url}" type="video/mp4"></video>'))
    print("🎬 Video displayed above!")
else:
    print("⚠️ No video found")
# Out:
# 🔍 Testing environment...
# ✅ Environment works!
# Observation shape: (84, 84, 1)
#
# 📊 Environment Info:
# Observation space: Box(0, 255, (84, 84, 1), uint8)
# Action space: Discrete(3)
#
# 🤖 Creating PPO model...
# Using cuda device
# Wrapping the env in a VecTransposeImage.
#
# 🚀 Training started... (this takes ~30-60 minutes)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# -----------------------------
# | time/              |      |
# |    fps             | 144  |
# |    iterations      | 1    |
# |    time_elapsed    | 14   |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 139         |
# |    iterations           | 2           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.010133972 |
# |    clip_fraction        | 0.0672      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.0373     |
# |    learning_rate        | 0.00025     |
# |    loss                 | -1.23e-05   |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00278    |
# |    value_loss           | 0.0313      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 136          |
# |    iterations           | 3            |
# |    time_elapsed         | 45           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0076205973 |
# |    clip_fraction        | 0.00498      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.0163       |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.00671     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00032     |
# |    value_loss           | 0.00539      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 136          |
# |    iterations           | 4            |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0124781085 |
# |    clip_fraction        | 0.0262       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.0498       |
# |    learning_rate        | 0.00025      |
# |    loss                 | -0.00095     |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00244     |
# |    value_loss           | 0.00302      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 136         |
# |    iterations           | 5           |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.005662951 |
# |    clip_fraction        | 0.00103     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.036       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -1.37e-05   |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -7.51e-05   |
# |    value_loss           | 0.00211     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 137         |
# |    iterations           | 6           |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.011997032 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.0121      |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.011      |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00808    |
# |    value_loss           | 0.00938     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 136        |
# |    iterations           | 7          |
# |    time_elapsed         | 104        |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.01218828 |
# |    clip_fraction        | 0.196      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.04      |
# |    explained_variance   | 0.00852    |
# |    learning_rate        | 0.00025    |
# |    loss                 | -0.0118    |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.0114    |
# |    value_loss           | 0.031      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 137         |
# |    iterations           | 8           |
# |    time_elapsed         | 119         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.015420841 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.991      |
# |    explained_variance   | 0.0211      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0342      |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0147     |
# |    value_loss           | 0.0527      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 137         |
# |    iterations           | 9           |
# |    time_elapsed         | 134         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.012767404 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.919      |
# |    explained_variance   | 0.0312      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0432      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0126     |
# |    value_loss           | 0.0748      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 137         |
# |    iterations           | 10          |
# |    time_elapsed         | 148         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.018461524 |
# |    clip_fraction        | 0.232       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.816      |
# |    explained_variance   | 0.434       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.017       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0227     |
# |    value_loss           | 0.0682      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 137         |
# |    iterations           | 11          |
# |    time_elapsed         | 163         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.010401433 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.717      |
# |    explained_variance   | 0.487       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0195      |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00827    |
# |    value_loss           | 0.0715      |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 137          |
# |    iterations           | 12           |
# |    time_elapsed         | 178          |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0074675237 |
# |    clip_fraction        | 0.11         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.641       |
# |    explained_variance   | 0.495        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0309       |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00854     |
# |    value_loss           | 0.0822       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 137         |
# |    iterations           | 13          |
# |    time_elapsed         | 193         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.006239295 |
# |    clip_fraction        | 0.0929      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.542      |
# |    explained_variance   | 0.37        |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0865      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00539    |
# |    value_loss           | 0.116       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 137          |
# |    iterations           | 14           |
# |    time_elapsed         | 207          |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0020171897 |
# |    clip_fraction        | 0.026        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.524       |
# |    explained_variance   | 0.436        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0122       |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00201     |
# |    value_loss           | 0.113        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 138          |
# |    iterations           | 15           |
# |    time_elapsed         | 222          |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0064580655 |
# |    clip_fraction        | 0.0497       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.485       |
# |    explained_variance   | 0.5          |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0387       |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00507     |
# |    value_loss           | 0.0989       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 138         |
# |    iterations           | 16          |
# |    time_elapsed         | 236         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.005218791 |
# |    clip_fraction        | 0.0691      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.405      |
# |    explained_variance   | 0.308       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0936      |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00415    |
# |    value_loss           | 0.148       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 138          |
# |    iterations           | 17           |
# |    time_elapsed         | 251          |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0012565634 |
# |    clip_fraction        | 0.0233       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.375       |
# |    explained_variance   | 0.501        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0283       |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00155     |
# |    value_loss           | 0.131        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 138          |
# |    iterations           | 18           |
# |    time_elapsed         | 266          |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0020663883 |
# |    clip_fraction        | 0.039        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.344       |
# |    explained_variance   | 0.657        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0236       |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00313     |
# |    value_loss           | 0.0886       |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 138          |
# |    iterations           | 19           |
# |    time_elapsed         | 280          |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0008172751 |
# |    clip_fraction        | 0.0156       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.335       |
# |    explained_variance   | 0.418        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.211        |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.000752    |
# |    value_loss           | 0.159        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 138         |
# |    iterations           | 20          |
# |    time_elapsed         | 294         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.002983342 |
# |    clip_fraction        | 0.0275      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.311      |
# |    explained_variance   | 0.445       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0446      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0059     |
# |    value_loss           | 0.154       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 139          |
# |    iterations           | 21           |
# |    time_elapsed         | 309          |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0021099178 |
# |    clip_fraction        | 0.0244       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.287       |
# |    explained_variance   | 0.596        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0418       |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00306     |
# |    value_loss           | 0.161        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 138         |
# |    iterations           | 22          |
# |    time_elapsed         | 324         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.002063599 |
# |    clip_fraction        | 0.0301      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.246      |
# |    explained_variance   | 0.654       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.112       |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00262    |
# |    value_loss           | 0.137       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 139          |
# |    iterations           | 23           |
# |    time_elapsed         | 338          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0010945546 |
# |    clip_fraction        | 0.0122       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.24        |
# |    explained_variance   | 0.673        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.087        |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00264     |
# |    value_loss           | 0.149        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 139          |
# |    iterations           | 24           |
# |    time_elapsed         | 353          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0021957154 |
# |    clip_fraction        | 0.0273       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.205       |
# |    explained_variance   | 0.735        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0523       |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00294     |
# |    value_loss           | 0.137        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 139           |
# |    iterations           | 25            |
# |    time_elapsed         | 367           |
# |    total_timesteps      | 51200         |
# | train/                  |               |
# |    approx_kl            | 0.00097159634 |
# |    clip_fraction        | 0.0203        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.183        |
# |    explained_variance   | 0.721         |
# |    learning_rate        | 0.00025       |
# |    loss                 | 0.0347        |
# |    n_updates            | 240           |
# |    policy_gradient_loss | -0.00193      |
# |    value_loss           | 0.142         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 139          |
# |    iterations           | 26           |
# |    time_elapsed         | 382          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0010038402 |
# |    clip_fraction        | 0.0111       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.18        |
# |    explained_variance   | 0.701        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0204       |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00325     |
# |    value_loss           | 0.171        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 139          |
# |    iterations           | 27           |
# |    time_elapsed         | 397          |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0009645126 |
# |    clip_fraction        | 0.0189       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.165       |
# |    explained_variance   | 0.656        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0849       |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00261     |
# |    value_loss           | 0.167        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 139          |
# |    iterations           | 28           |
# |    time_elapsed         | 411          |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0027366737 |
# |    clip_fraction        | 0.0147       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.192       |
# |    explained_variance   | 0.799        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0641       |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00324     |
# |    value_loss           | 0.134        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 139          |
# |    iterations           | 29           |
# |    time_elapsed         | 426          |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0014189279 |
# |    clip_fraction        | 0.0175       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.171       |
# |    explained_variance   | 0.793        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.17         |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00117     |
# |    value_loss           | 0.142        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 139          |
# |    iterations           | 30           |
# |    time_elapsed         | 440          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0015657969 |
# |    clip_fraction        | 0.0167       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.167       |
# |    explained_variance   | 0.762        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0427       |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00388     |
# |    value_loss           | 0.173        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 139          |
# |    iterations           | 31           |
# |    time_elapsed         | 455          |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0015815264 |
# |    clip_fraction        | 0.0152       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.192       |
# |    explained_variance   | 0.761        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0638       |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00238     |
# |    value_loss           | 0.174        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 139          |
# |    iterations           | 32           |
# |    time_elapsed         | 470          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0016554478 |
# |    clip_fraction        | 0.0145       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.17        |
# |    explained_variance   | 0.814        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.047        |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00304     |
# |    value_loss           | 0.156        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 139         |
# |    iterations           | 33          |
# |    time_elapsed         | 484         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.003304716 |
# |    clip_fraction        | 0.0199      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.202      |
# |    explained_variance   | 0.787       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0544      |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00358    |
# |    value_loss           | 0.177       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 139          |
# |    iterations           | 34           |
# |    time_elapsed         | 499          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0028666875 |
# |    clip_fraction        | 0.031        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.227       |
# |    explained_variance   | 0.791        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0323       |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00556     |
# |    value_loss           | 0.167        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 139          |
# |    iterations           | 35           |
# |    time_elapsed         | 513          |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0037163463 |
# |    clip_fraction        | 0.0336       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.248       |
# |    explained_variance   | 0.8          |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0642       |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00704     |
# |    value_loss           | 0.149        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 139          |
# |    iterations           | 36           |
# |    time_elapsed         | 528          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0062838937 |
# |    clip_fraction        | 0.038        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.271       |
# |    explained_variance   | 0.809        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.051        |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00672     |
# |    value_loss           | 0.158        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 139          |
# |    iterations           | 37           |
# |    time_elapsed         | 543          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0031414456 |
# |    clip_fraction        | 0.0338       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.272       |
# |    explained_variance   | 0.847        |
# |    learning_rate        | 0.00025      |
# |    loss                 | 0.0882       |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00696     |
# |    value_loss           | 0.164        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 139         |
# |    iterations           | 38          |
# |    time_elapsed         | 557         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.005926771 |
# |    clip_fraction        | 0.0506      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.287      |
# |    explained_variance   | 0.877       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.00789     |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0105     |
# |    value_loss           | 0.122       |
# -----------------------------------------
# --------------------------------------
# | time/                   |          |
# |    fps                  | 139      |
# |    iterations           | 39       |
# |    time_elapsed         | 572      |
# |    total_timesteps      | 79872    |
# | train/                  |          |
# |    approx_kl            | 0.008939 |
# |    clip_fraction        | 0.0688   |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.329   |
# |    explained_variance   | 0.834    |
# |    learning_rate        | 0.00025  |
# |    loss                 | 0.0162   |
# |    n_updates            | 380      |
# |    policy_gradient_loss | -0.0132  |
# |    value_loss           | 0.147    |
# --------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 139         |
# |    iterations           | 40          |
# |    time_elapsed         | 586         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.013270659 |
# |    clip_fraction        | 0.0861      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.343      |
# |    explained_variance   | 0.872       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.00698     |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0188     |
# |    value_loss           | 0.122       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 139         |
# |    iterations           | 41          |
# |    time_elapsed         | 601         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.010525037 |
# |    clip_fraction        | 0.0674      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.339      |
# |    explained_variance   | 0.842       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0305      |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0175     |
# |    value_loss           | 0.123       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 139         |
# |    iterations           | 42          |
# |    time_elapsed         | 616         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.009851813 |
# |    clip_fraction        | 0.0775      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.336      |
# |    explained_variance   | 0.864       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0219      |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.016      |
# |    value_loss           | 0.112       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 139         |
# |    iterations           | 43          |
# |    time_elapsed         | 631         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.012759782 |
# |    clip_fraction        | 0.0885      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.318      |
# |    explained_variance   | 0.89        |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0167      |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0192     |
# |    value_loss           | 0.101       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 139         |
# |    iterations           | 44          |
# |    time_elapsed         | 645         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.014702385 |
# |    clip_fraction        | 0.0897      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.37       |
# |    explained_variance   | 0.887       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.00436     |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.02       |
# |    value_loss           | 0.103       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 139         |
# |    iterations           | 45          |
# |    time_elapsed         | 660         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.014865549 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.385      |
# |    explained_variance   | 0.89        |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.0219      |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0227     |
# |    value_loss           | 0.0957      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 139         |
# |    iterations           | 46          |
# |    time_elapsed         | 675         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.023841951 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.393      |
# |    explained_variance   | 0.91        |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0114     |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0261     |
# |    value_loss           | 0.0765      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 139         |
# |    iterations           | 47          |
# |    time_elapsed         | 690         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.017940689 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.391      |
# |    explained_variance   | 0.918       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.024      |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0249     |
# |    value_loss           | 0.0843      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 139         |
# |    iterations           | 48          |
# |    time_elapsed         | 704         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.016945573 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.383      |
# |    explained_variance   | 0.924       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 0.00644     |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0244     |
# |    value_loss           | 0.0884      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 139         |
# |    iterations           | 49          |
# |    time_elapsed         | 719         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.019888526 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.402      |
# |    explained_variance   | 0.927       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0222     |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.027      |
# |    value_loss           | 0.0833      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 139         |
# |    iterations           | 50          |
# |    time_elapsed         | 734         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.016291345 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.382      |
# |    explained_variance   | 0.929       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.000821   |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0257     |
# |    value_loss           | 0.0766      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 139         |
# |    iterations           | 51          |
# |    time_elapsed         | 750         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.019742243 |
# |    clip_fraction        | 0.13        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.366      |
# |    explained_variance   | 0.934       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0216     |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.027      |
# |    value_loss           | 0.0831      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 139         |
# |    iterations           | 52          |
# |    time_elapsed         | 765         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.019602805 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.389      |
# |    explained_variance   | 0.935       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.05       |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0291     |
# |    value_loss           | 0.0737      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 139         |
# |    iterations           | 53          |
# |    time_elapsed         | 779         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.024833785 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.418      |
# |    explained_variance   | 0.93        |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0426     |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0351     |
# |    value_loss           | 0.0712      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 139         |
# |    iterations           | 54          |
# |    time_elapsed         | 794         |
# |    total_timesteps      | 110592      |
# | train/                  |             |
# |    approx_kl            | 0.025716832 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.421      |
# |    explained_variance   | 0.948       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.018      |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.0331     |
# |    value_loss           | 0.0546      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 139         |
# |    iterations           | 55          |
# |    time_elapsed         | 809         |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.024942692 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.406      |
# |    explained_variance   | 0.944       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0155     |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.0317     |
# |    value_loss           | 0.0626      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 139         |
# |    iterations           | 56          |
# |    time_elapsed         | 825         |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.025309205 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.405      |
# |    explained_variance   | 0.95        |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0176     |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.0328     |
# |    value_loss           | 0.0603      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 139         |
# |    iterations           | 57          |
# |    time_elapsed         | 839         |
# |    total_timesteps      | 116736      |
# | train/                  |             |
# |    approx_kl            | 0.028976075 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.458      |
# |    explained_variance   | 0.935       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0447     |
# |    n_updates            | 560         |
# |    policy_gradient_loss | -0.0387     |
# |    value_loss           | 0.0717      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 138         |
# |    iterations           | 58          |
# |    time_elapsed         | 854         |
# |    total_timesteps      | 118784      |
# | train/                  |             |
# |    approx_kl            | 0.032131452 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.44       |
# |    explained_variance   | 0.937       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0505     |
# |    n_updates            | 570         |
# |    policy_gradient_loss | -0.0383     |
# |    value_loss           | 0.0668      |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 138        |
# |    iterations           | 59         |
# |    time_elapsed         | 869        |
# |    total_timesteps      | 120832     |
# | train/                  |            |
# |    approx_kl            | 0.03490112 |
# |    clip_fraction        | 0.198      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.436     |
# |    explained_variance   | 0.942      |
# |    learning_rate        | 0.00025    |
# |    loss                 | 0.0033     |
# |    n_updates            | 580        |
# |    policy_gradient_loss | -0.0359    |
# |    value_loss           | 0.0618     |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 138         |
# |    iterations           | 60          |
# |    time_elapsed         | 884         |
# |    total_timesteps      | 122880      |
# | train/                  |             |
# |    approx_kl            | 0.029941484 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.457      |
# |    explained_variance   | 0.929       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0479     |
# |    n_updates            | 590         |
# |    policy_gradient_loss | -0.0392     |
# |    value_loss           | 0.0593      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 138         |
# |    iterations           | 61          |
# |    time_elapsed         | 899         |
# |    total_timesteps      | 124928      |
# | train/                  |             |
# |    approx_kl            | 0.030874036 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.465      |
# |    explained_variance   | 0.943       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0361     |
# |    n_updates            | 600         |
# |    policy_gradient_loss | -0.0389     |
# |    value_loss           | 0.0529      |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 138        |
# |    iterations           | 62         |
# |    time_elapsed         | 915        |
# |    total_timesteps      | 126976     |
# | train/                  |            |
# |    approx_kl            | 0.03554352 |
# |    clip_fraction        | 0.224      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.506     |
# |    explained_variance   | 0.954      |
# |    learning_rate        | 0.00025    |
# |    loss                 | -0.0514    |
# |    n_updates            | 610        |
# |    policy_gradient_loss | -0.0426    |
# |    value_loss           | 0.0465     |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 138         |
# |    iterations           | 63          |
# |    time_elapsed         | 931         |
# |    total_timesteps      | 129024      |
# | train/                  |             |
# |    approx_kl            | 0.038306847 |
# |    clip_fraction        | 0.228       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.467      |
# |    explained_variance   | 0.955       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.048      |
# |    n_updates            | 620         |
# |    policy_gradient_loss | -0.0416     |
# |    value_loss           | 0.0455      |
# ...
# |    time_elapsed         | 3320       |
# |    total_timesteps      | 462848     |
# | train/                  |            |
# |    approx_kl            | 0.12969312 |
# |    clip_fraction        | 0.22       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.22      |
# |    explained_variance   | 0.953      |
# |    learning_rate        | 0.00025    |
# |    loss                 | -0.0424    |
# |    n_updates            | 2250       |
# |    policy_gradient_loss | -0.0403    |
# |    value_loss           | 0.0232     |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 139        |
# |    iterations           | 227        |
# |    time_elapsed         | 3335       |
# |    total_timesteps      | 464896     |
# | train/                  |            |
# |    approx_kl            | 0.14718062 |
# |    clip_fraction        | 0.207      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.217     |
# |    explained_variance   | 0.954      |
# |    learning_rate        | 0.00025    |
# |    loss                 | -0.0388    |
# |    n_updates            | 2260       |
# |    policy_gradient_loss | -0.032     |
# |    value_loss           | 0.0261     |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 139        |
# |    iterations           | 228        |
# |    time_elapsed         | 3350       |
# |    total_timesteps      | 466944     |
# | train/                  |            |
# |    approx_kl            | 0.14561012 |
# |    clip_fraction        | 0.23       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.231     |
# |    explained_variance   | 0.95       |
# |    learning_rate        | 0.00025    |
# |    loss                 | -0.0407    |
# |    n_updates            | 2270       |
# |    policy_gradient_loss | -0.0366    |
# |    value_loss           | 0.0247     |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 139       |
# |    iterations           | 229       |
# |    time_elapsed         | 3364      |
# |    total_timesteps      | 468992    |
# | train/                  |           |
# |    approx_kl            | 0.1547991 |
# |    clip_fraction        | 0.235     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.23     |
# |    explained_variance   | 0.944     |
# |    learning_rate        | 0.00025   |
# |    loss                 | -0.0342   |
# |    n_updates            | 2280      |
# |    policy_gradient_loss | -0.0392   |
# |    value_loss           | 0.0322    |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 139         |
# |    iterations           | 230         |
# |    time_elapsed         | 3379        |
# |    total_timesteps      | 471040      |
# | train/                  |             |
# |    approx_kl            | 0.122797005 |
# |    clip_fraction        | 0.216       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.212      |
# |    explained_variance   | 0.949       |
# |    learning_rate        | 0.00025     |
# |    loss                 | -0.0462     |
# |    n_updates            | 2290        |
# |    policy_gradient_loss | -0.0403     |
# |    value_loss           | 0.0277      |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 139        |
# |    iterations           | 231        |
# |    time_elapsed         | 3394       |
# |    total_timesteps      | 473088     |
# | train/                  |            |
# |    approx_kl            | 0.13727254 |
# |    clip_fraction        | 0.228      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.228     |
# |    explained_variance   | 0.951      |
# |    learning_rate        | 0.00025    |
# |    loss                 | -0.0431    |
# |    n_updates            | 2300       |
# |    policy_gradient_loss | -0.0371    |
# |    value_loss           | 0.021      |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 139        |
# |    iterations           | 232        |
# |    time_elapsed         | 3408       |
# |    total_timesteps      | 475136     |
# | train/                  |            |
# |    approx_kl            | 0.16921207 |
# |    clip_fraction        | 0.218      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.214     |
# |    explained_variance   | 0.961      |
# |    learning_rate        | 0.00025    |
# |    loss                 | -0.0646    |
# |    n_updates            | 2310       |
# |    policy_gradient_loss | -0.0384    |
# |    value_loss           | 0.0207     |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 139        |
# |    iterations           | 233        |
# |    time_elapsed         | 3423       |
# |    total_timesteps      | 477184     |
# | train/                  |            |
# |    approx_kl            | 0.14000556 |
# |    clip_fraction        | 0.209      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.209     |
# |    explained_variance   | 0.967      |
# |    learning_rate        | 0.00025    |
# |    loss                 | -0.0476    |
# |    n_updates            | 2320       |
# |    policy_gradient_loss | -0.0337    |
# |    value_loss           | 0.0185     |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 139       |
# |    iterations           | 234       |
# |    time_elapsed         | 3437      |
# |    total_timesteps      | 479232    |
# | train/                  |           |
# |    approx_kl            | 0.1747905 |
# |    clip_fraction        | 0.21      |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.19     |
# |    explained_variance   | 0.961     |
# |    learning_rate        | 0.00025   |
# |    loss                 | -0.0237   |
# |    n_updates            | 2330      |
# |    policy_gradient_loss | -0.0331   |
# |    value_loss           | 0.0234    |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 139        |
# |    iterations           | 235        |
# |    time_elapsed         | 3452       |
# |    total_timesteps      | 481280     |
# | train/                  |            |
# |    approx_kl            | 0.16247605 |
# |    clip_fraction        | 0.209      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.195     |
# |    explained_variance   | 0.961      |
# |    learning_rate        | 0.00025    |
# |    loss                 | -0.0423    |
# |    n_updates            | 2340       |
# |    policy_gradient_loss | -0.0332    |
# |    value_loss           | 0.0178     |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 139        |
# |    iterations           | 236        |
# |    time_elapsed         | 3467       |
# |    total_timesteps      | 483328     |
# | train/                  |            |
# |    approx_kl            | 0.16101351 |
# |    clip_fraction        | 0.208      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.206     |
# |    explained_variance   | 0.963      |
# |    learning_rate        | 0.00025    |
# |    loss                 | -0.0712    |
# |    n_updates            | 2350       |
# |    policy_gradient_loss | -0.037     |
# |    value_loss           | 0.0188     |
# ----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 139       |
# |    iterations           | 237       |
# |    time_elapsed         | 3482      |
# |    total_timesteps      | 485376    |
# | train/                  |           |
# |    approx_kl            | 0.1717816 |
# |    clip_fraction        | 0.236     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.216    |
# |    explained_variance   | 0.961     |
# |    learning_rate        | 0.00025   |
# |    loss                 | -0.00265  |
# |    n_updates            | 2360      |
# |    policy_gradient_loss | -0.0335   |
# |    value_loss           | 0.0201    |
# ---------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 139        |
# |    iterations           | 238        |
# |    time_elapsed         | 3496       |
# |    total_timesteps      | 487424     |
# | train/                  |            |
# |    approx_kl            | 0.14150217 |
# |    clip_fraction        | 0.24       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.225     |
# |    explained_variance   | 0.951      |
# |    learning_rate        | 0.00025    |
# |    loss                 | -0.0528    |
# |    n_updates            | 2370       |
# |    policy_gradient_loss | -0.0362    |
# |    value_loss           | 0.024      |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 139        |
# |    iterations           | 239        |
# |    time_elapsed         | 3511       |
# |    total_timesteps      | 489472     |
# | train/                  |            |
# |    approx_kl            | 0.15141112 |
# |    clip_fraction        | 0.216      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.213     |
# |    explained_variance   | 0.971      |
# |    learning_rate        | 0.00025    |
# |    loss                 | -0.0475    |
# |    n_updates            | 2380       |
# |    policy_gradient_loss | -0.0344    |
# |    value_loss           | 0.0168     |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 139        |
# |    iterations           | 240        |
# |    time_elapsed         | 3525       |
# |    total_timesteps      | 491520     |
# | train/                  |            |
# |    approx_kl            | 0.14510664 |
# |    clip_fraction        | 0.215      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.197     |
# |    explained_variance   | 0.964      |
# |    learning_rate        | 0.00025    |
# |    loss                 | -0.0663    |
# |    n_updates            | 2390       |
# |    policy_gradient_loss | -0.0357    |
# |    value_loss           | 0.0211     |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 139        |
# |    iterations           | 241        |
# |    time_elapsed         | 3540       |
# |    total_timesteps      | 493568     |
# | train/                  |            |
# |    approx_kl            | 0.16696757 |
# |    clip_fraction        | 0.214      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.199     |
# |    explained_variance   | 0.97       |
# |    learning_rate        | 0.00025    |
# |    loss                 | -0.0473    |
# |    n_updates            | 2400       |
# |    policy_gradient_loss | -0.0356    |
# |    value_loss           | 0.0227     |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 139        |
# |    iterations           | 242        |
# |    time_elapsed         | 3555       |
# |    total_timesteps      | 495616     |
# | train/                  |            |
# |    approx_kl            | 0.17768008 |
# |    clip_fraction        | 0.223      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.209     |
# |    explained_variance   | 0.966      |
# |    learning_rate        | 0.00025    |
# |    loss                 | -0.0332    |
# |    n_updates            | 2410       |
# |    policy_gradient_loss | -0.043     |
# |    value_loss           | 0.0191     |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 139        |
# |    iterations           | 243        |
# |    time_elapsed         | 3569       |
# |    total_timesteps      | 497664     |
# | train/                  |            |
# |    approx_kl            | 0.14935333 |
# |    clip_fraction        | 0.217      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.221     |
# |    explained_variance   | 0.955      |
# |    learning_rate        | 0.00025    |
# |    loss                 | -0.0581    |
# |    n_updates            | 2420       |
# |    policy_gradient_loss | -0.041     |
# |    value_loss           | 0.0244     |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 139        |
# |    iterations           | 244        |
# |    time_elapsed         | 3583       |
# |    total_timesteps      | 499712     |
# | train/                  |            |
# |    approx_kl            | 0.18274699 |
# |    clip_fraction        | 0.219      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.19      |
# |    explained_variance   | 0.973      |
# |    learning_rate        | 0.00025    |
# |    loss                 | -0.0621    |
# |    n_updates            | 2430       |
# |    policy_gradient_loss | -0.0371    |
# |    value_loss           | 0.0184     |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 139        |
# |    iterations           | 245        |
# |    time_elapsed         | 3598       |
# |    total_timesteps      | 501760     |
# | train/                  |            |
# |    approx_kl            | 0.18368332 |
# |    clip_fraction        | 0.212      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.202     |
# |    explained_variance   | 0.958      |
# |    learning_rate        | 0.00025    |
# |    loss                 | -0.0321    |
# |    n_updates            | 2440       |
# |    policy_gradient_loss | -0.0356    |
# |    value_loss           | 0.0316     |
# ----------------------------------------
#
# ✅ Training complete!
#
# 📊 Evaluating...
# /usr/local/lib/python3.12/dist-packages/stable_baselines3/common/evaluation.py:70: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# 🎯 Mean Reward: 19.10 ± 6.20
#
# 🎥 Recording video...
# Saving video to /content/videos/ppo-freeway-step-0-to-step-2000.mp4
# /usr/local/lib/python3.12/dist-packages/moviepy/config_defaults.py:47: SyntaxWarning: invalid escape sequence '\P'
#   IMAGEMAGICK_BINARY = r"C:\Program Files\ImageMagick-6.8.8-Q16\magick.exe"
# Moviepy - Building video /content/videos/ppo-freeway-step-0-to-step-2000.mp4.
# Moviepy - Writing video /content/videos/ppo-freeway-step-0-to-step-2000.mp4
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# Moviepy - Done !
# Moviepy - video ready /content/videos/ppo-freeway-step-0-to-step-2000.mp4
# ✅ Video saved in ./videos/
# <video width="400" controls><source src="data:video/mp4;base64,..." type="video/mp4"></video>
# 🎬 Video displayed above!
